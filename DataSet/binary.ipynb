# %%
import pandas as pd
from fxpmath import Fxp
from sklearn.model_selection import train_test_split
from scipy import stats
import numpy as np

# %%
def convert(x):
    y = Fxp(x, signed=True, dtype='S4.12')

    return int(y.bin(frac_dot=False), 2)

# %%
# df = pd.read_csv('winequality-red.csv')
df = pd.read_csv('ParisHousing.csv')
df.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# ...

# %%
df.dropna
df.describe()
# Out:
#        squareMeters  numberOfRooms       hasYard       hasPool        floors  \
# count   10000.00000   10000.000000  10000.000000  10000.000000  10000.000000
# mean    49870.13120      50.358400      0.508700      0.496800     50.276300
# std     28774.37535      28.816696      0.499949      0.500015     28.889171
# min        89.00000       1.000000      0.000000      0.000000      1.000000
# 25%     25098.50000      25.000000      0.000000      0.000000     25.000000
# 50%     50105.50000      50.000000      1.000000      0.000000     50.000000
# 75%     74609.75000      75.000000      1.000000      1.000000     76.000000
# max     99999.00000     100.000000      1.000000      1.000000    100.000000
#
#            cityCode  cityPartRange  numPrevOwners         made    isNewBuilt  \
# count  10000.000000   10000.000000   10000.000000  10000.00000  10000.000000
# mean   50225.486100       5.510100       5.521700   2005.48850      0.499100
# ...

# %%
df.insert(0, 'price', df.pop('price'))
# df.insert(0, 'quality', df.pop('quality'))
df.head()
# Out:
#        price  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0  7559081.5         75523              3        0        1      63      9373
# 1  8085989.5         80771             39        1        1      98     39381
# 2  5574642.1         55712             58        0        1      19     34457
# 3  3232561.2         32316             47        0        0       6     27939
# 4  7055052.0         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom
# ...

# %%
df = df.drop(['hasGuestRoom', 'hasStorageRoom'], axis=1)
df.describe()
# Out:
#               price  squareMeters  numberOfRooms       hasYard       hasPool  \
# count  1.000000e+04   10000.00000   10000.000000  10000.000000  10000.000000
# mean   4.993448e+06   49870.13120      50.358400      0.508700      0.496800
# std    2.877424e+06   28774.37535      28.816696      0.499949      0.500015
# min    1.031350e+04      89.00000       1.000000      0.000000      0.000000
# 25%    2.516402e+06   25098.50000      25.000000      0.000000      0.000000
# 50%    5.016180e+06   50105.50000      50.000000      1.000000      0.000000
# 75%    7.469092e+06   74609.75000      75.000000      1.000000      1.000000
# max    1.000677e+07   99999.00000     100.000000      1.000000      1.000000
#
#              floors      cityCode  cityPartRange  numPrevOwners         made  \
# count  10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# mean      50.276300  50225.486100       5.510100       5.521700   2005.48850
# ...

# %%
len(df.columns)
# Out:
# 15

# %%
df=(df-df.min())/(df.max()-df.min())
df[:10]
# Out:
#       price  squareMeters  numberOfRooms  hasYard  hasPool    floors  \
# 0  0.755144      0.755020       0.020202      0.0      1.0  0.626263
# 1  0.807854      0.807547       0.383838      1.0      1.0  0.979798
# 2  0.556630      0.556731       0.575758      0.0      1.0  0.181818
# 3  0.322339      0.322560       0.464646      0.0      0.0  0.050505
# 4  0.704723      0.704034       0.181818      1.0      1.0  0.898990
# 5  0.391772      0.391693       0.353535      0.0      1.0  0.161616
# 6  0.586814      0.586458       0.090909      1.0      1.0  0.989899
# 7  0.868963      0.869182       1.000000      1.0      0.0  0.101010
# 8  0.514556      0.514793       0.020202      0.0      0.0  0.606061
# 9  0.396198      0.396327       0.414141      0.0      0.0  0.141414
#
#    cityCode  cityPartRange  numPrevOwners      made  isNewBuilt  \
# 0  0.093747       0.222222       0.777778  0.483871         0.0
# 1  0.393977       0.777778       0.555556  0.806452         1.0
# ...

# %%
df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
# Out:
#          price  squareMeters  numberOfRooms  hasYard  hasPool    floors  \
# 0     0.755144      0.755020       0.020202      0.0      1.0  0.626263
# 1     0.807854      0.807547       0.383838      1.0      1.0  0.979798
# 2     0.556630      0.556731       0.575758      0.0      1.0  0.181818
# 3     0.322339      0.322560       0.464646      0.0      0.0  0.050505
# 4     0.704723      0.704034       0.181818      1.0      1.0  0.898990
# ...        ...           ...            ...      ...      ...       ...
# 9995  0.016617      0.016385       0.888889      0.0      1.0  0.040404
# 9996  0.443973      0.443539       0.282828      1.0      1.0  0.111111
# 9997  0.838269      0.838274       0.020202      0.0      0.0  0.686869
# 9998  0.589688      0.590001       0.696970      0.0      0.0  0.959596
# 9999  0.013644      0.013522       0.838384      0.0      0.0  0.484848
#
#       cityCode  cityPartRange  numPrevOwners      made  isNewBuilt  \
# ...

# %%
train, test = train_test_split(df, test_size=0.9, random_state=12)

# %%
train.describe()
# Out:
#              price  squareMeters  numberOfRooms      hasYard      hasPool  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean      0.500440      0.500218       0.495424     0.533000     0.474000
# std       0.277780      0.277933       0.297061     0.499159     0.499573
# min       0.000518      0.000390       0.000000     0.000000     0.000000
# 25%       0.274637      0.273804       0.242424     0.000000     0.000000
# 50%       0.509938      0.509769       0.494949     1.000000     0.000000
# 75%       0.724574      0.724367       0.757576     1.000000     1.000000
# max       0.996931      0.996657       1.000000     1.000000     1.000000
#
#             floors     cityCode  cityPartRange  numPrevOwners         made  \
# count  1000.000000  1000.000000    1000.000000    1000.000000  1000.000000
# mean      0.482323     0.517371       0.498222       0.502222     0.510323
# std       0.290492     0.298153       0.318134       0.312210     0.301804
# ...

# %%
test.describe()
# Out:
#              price  squareMeters  numberOfRooms      hasYard      hasPool  \
# count  9000.000000   9000.000000    9000.000000  9000.000000  9000.000000
# mean      0.498273      0.498042       0.498919     0.506000     0.499333
# std       0.288955      0.289114       0.290420     0.499992     0.500027
# min       0.000000      0.000000       0.000000     0.000000     0.000000
# 25%       0.248760      0.248549       0.242424     0.000000     0.000000
# 50%       0.500141      0.499775       0.494949     1.000000     0.000000
# 75%       0.747659      0.747405       0.747475     1.000000     1.000000
# max       1.000000      1.000000       1.000000     1.000000     1.000000
#
#             floors     cityCode  cityPartRange  numPrevOwners         made  \
# count  9000.000000  9000.000000    9000.000000    9000.000000  9000.000000
# mean      0.499453     0.500821       0.501444       0.502432     0.498441
# std       0.291922     0.289286       0.319238       0.317997     0.300082
# ...

# %%
lines_train = []
for index, row in train.iterrows():
    x = []
    for j in row:
        x.append(str(hex(convert(j)))[2:])
    lines_train.append(' '.join(x))

# %%
# Uncomment to write train file
with open('..\\sim_1\\new\\mem_large_14.mem', 'w') as f:
    f.write('\n'.join(lines_train))

# %%
train.to_csv('Housing_Train_14.csv', index=False, na_rep='Unkown', header=False)

# %%
test.to_csv('Housing_Test_14.csv', index=False, na_rep='Unkown', header=False)
